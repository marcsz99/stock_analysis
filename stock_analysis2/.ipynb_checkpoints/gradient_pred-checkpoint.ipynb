# %%
import os 
os.chdir('/Users/mszwagrzak')

# %%
import matplotlib.pyplot as plt
from pickle_loader import pickle_loader
import datetime as dt
import pandas as pd
import numpy as np
import pickle

# %%
technical_data = pickle_loader(r"C:\Users\mszwagrzak\OneDrive - Genomics England Ltd\Documents\stock_analysis2\batch_1\technical_us.pickle")

# %%
technical_data['MMM'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 503 entries, 2021-09-30 00:00:00-04:00 to 2023-09-29 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          503 non-null    float64
#  1   High          503 non-null    float64
#  2   Low           503 non-null    float64
#  3   Close         503 non-null    float64
#  4   Volume        503 non-null    int64
#  5   Dividends     503 non-null    float64
#  6   Stock Splits  503 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# ### Remove Tickers that don't contain the full dataset

# %%
def tech_clean(dataset):
    clean_dataset = dataset.copy()
    tickers = list(technical_data.keys())
    removed_tickers = []
    
    for ticker in tickers:
        if len(dataset[ticker]) == 0: # Remove tickers that are empty 
            clean_dataset.pop(ticker, None)
            removed_tickers.append(ticker)
        else: # Remove tickers that don't contain the full dataset 
            first_time = dataset[ticker].index.to_pydatetime()[0].strftime('%d-%m-%Y')
            last_time = dataset[ticker].index.to_pydatetime()[-1].strftime('%d-%m-%Y')
            if first_time != '30-09-2021' or last_time != '29-09-2023':
                clean_dataset.pop(ticker, None)
                removed_tickers.append(ticker)
    
    return clean_dataset, removed_tickers

# %%
clean_tech_data, removed_tickers = tech_clean(technical_data)

# %%
list(clean_tech_data['MMM'].index)
# Out:
# [Timestamp('2021-09-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-10-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-11-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-11-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-11-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-11-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-11-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2021-11-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-11 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-12 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-15 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-16 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-17 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-18 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-19 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-22 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-24 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-26 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-29 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-11-30 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-01 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-02 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-06 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-13 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-14 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-15 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-16 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-17 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-20 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-21 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-22 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-27 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-28 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-29 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-30 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2021-12-31 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-04 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-05 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-06 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-11 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-12 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-13 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-14 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-18 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-19 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-20 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-21 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-24 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-25 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-26 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-27 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-28 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-01-31 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-01 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-02 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-04 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-11 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-14 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-15 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-16 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-17 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-18 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-22 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-24 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-25 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-02-28 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-01 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-02 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-04 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-11 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-03-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-03-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-04-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-05-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-07-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-08-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-10-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-11-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-11-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-11-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-11-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2022-11-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-11 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-14 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-15 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-16 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-17 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-18 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-21 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-22 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-25 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-28 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-29 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-11-30 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-01 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-02 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-05 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-06 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-12 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-13 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-14 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-15 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-16 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-19 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-20 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-21 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-22 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-27 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-28 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-29 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-04 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-05 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-06 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-11 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-12 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-13 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-17 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-18 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-19 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-20 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-24 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-25 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-26 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-27 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-30 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-01-31 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-01 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-02 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-06 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-13 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-14 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-15 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-16 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-17 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-21 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-22 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-23 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-24 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-27 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-02-28 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-01 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-02 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-03 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-06 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-07 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-08 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-09 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-10 00:00:00-0500', tz='America/New_York'),
#  Timestamp('2023-03-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-03-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-04-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-05-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-06-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-07-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-02 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-03 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-04 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-09 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-10 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-16 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-17 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-23 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-24 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-29 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-30 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-08-31 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-01 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-05 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-06 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-07 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-08 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-11 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-12 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-13 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-14 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-15 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-18 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-19 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-20 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-21 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-22 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-25 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-26 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-27 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-28 00:00:00-0400', tz='America/New_York'),
#  Timestamp('2023-09-29 00:00:00-0400', tz='America/New_York')]

# %%
def get_train_test_subset(dict_technical_data, start_date, end_date):
    """
    This function takes a dictionary of technical data as input and returns a dictionary 
    containing only the subset of technical data used in the train/test set.
    
    Parameters:
    dict_fundamental_data : A dictionary where the key is the stock and the value is a 
    dataframe of the given stocks technical data.
    
    start_date: string in the format 'YYYY-MM-DD' and is start date of the train/test set
    
    end_date: string in the format 'YYYY-MM-DD' and is end date of the train/test set
    
    Returns:
    dict_train_test: A dict where the key is the stock and the value is a df containing 
    only the dates between start_date and end_date
    """
    # Convert the start and end date in pd.Timestamp format
    start_date = pd.Timestamp(start_date + ' 00:00:00-0400', tz='America/New_York')
    end_date = pd.Timestamp(end_date + ' 00:00:00-0400', tz='America/New_York')
    
    dict_train_test = {}
    
    for stock, data in dict_technical_data.items():
        stock_df = data[(data.index >= start_date) & (data.index <= end_date)]
        dict_train_test[stock] = stock_df
    
    return dict_train_test

# %%
dict_train_test = get_train_test_subset(clean_tech_data, '2021-09-30', '2023-06-30')

# %% [markdown]
# ### Helper Fuctions for spliting the training chunks

# %%
def find_nearest_date(date_indexes, single_date):
    """
    Finds the nearest date in the array of pandas datetime indexes to the given single datetime index.
    
    Parameters:
    date_indexes (array-like): Array of pandas datetime indexes
    single_date (pandas.Timestamp): Single pandas datetime index
    
    Returns:
    pandas.Timestamp: Nearest datetime index in the array
    """
    # Calculate absolute differences between single_date and each date in date_indexes
    differences = abs(pd.Index(date_indexes) - single_date)
    
    # Find the index of the minimum difference
    min_diff_index = differences.argmin()
    
    # Return the nearest date
    return date_indexes[min_diff_index]

# Example usage:
# Assuming 'date_indexes' is an array of pandas datetime indexes
# and 'single_date' is a single pandas datetime index
nearest_date = find_nearest_date(clean_tech_data['MMM'].index, clean_tech_data['MMM'].index[0])
print(nearest_date)
# Out:
# 2021-09-30 00:00:00-04:00

# %% [markdown]
# #### Find  1, 3, 6 and 12 month chunks before pred date

# %%
import pandas as pd

def n_chunks(chunk_sizes, start_date, end_date):
    n_chunk_dates = {}

    for chunk in chunk_sizes:
        n_chunk_dates[chunk] = split_into_chunks(chunk)

    return n_chunk_dates


def split_into_chunks(n_months_chunk_size):
    chunks = []
    
    current_start = start_date

    while current_start <= (end_date - pd.DateOffset(months=n_months_chunk_size)):
        current_end = current_start + pd.DateOffset(months=n_months_chunk_size)
        # Slice the dates that fall within the chunk size
        chunks.append((current_start, current_end))
        # Move the start date forward by the interval provided
        current_start += pd.DateOffset(months=3)
    
    return chunks

dates = list(clean_tech_data['MMM'].index)
start_date = dates[0]
end_date = dates[-1]

chunk_dates = n_chunks((1,3,6,12), start_date, end_date)

# %%
print(chunk_dates[1])
# Out:
# [(Timestamp('2021-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2021-10-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2021-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2022-01-30 00:00:00-0500', tz='America/New_York')), (Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-04-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-07-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-10-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2023-01-30 00:00:00-0500', tz='America/New_York')), (Timestamp('2023-03-30 00:00:00-0400', tz='America/New_York'), Timestamp('2023-04-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2023-06-30 00:00:00-0400', tz='America/New_York'), Timestamp('2023-07-30 00:00:00-0400', tz='America/New_York'))]

# %%
print(chunk_dates[3])
# Out:
# [(Timestamp('2021-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2021-12-30 00:00:00-0500', tz='America/New_York')), (Timestamp('2021-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York')), (Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2023-03-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2023-03-30 00:00:00-0400', tz='America/New_York'), Timestamp('2023-06-30 00:00:00-0400', tz='America/New_York'))]

# %%
print(chunk_dates[6])
# Out:
# [(Timestamp('2021-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2021-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York')), (Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2023-03-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2023-06-30 00:00:00-0400', tz='America/New_York'))]

# %%
print(chunk_dates[12])
# Out:
# [(Timestamp('2021-09-30 00:00:00-0400', tz='America/New_York'), Timestamp('2022-09-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2021-12-30 00:00:00-0500', tz='America/New_York'), Timestamp('2022-12-30 00:00:00-0500', tz='America/New_York')), (Timestamp('2022-03-30 00:00:00-0400', tz='America/New_York'), Timestamp('2023-03-30 00:00:00-0400', tz='America/New_York')), (Timestamp('2022-06-30 00:00:00-0400', tz='America/New_York'), Timestamp('2023-06-30 00:00:00-0400', tz='America/New_York'))]

# %% [markdown]
# ## Get Grad

# %%
class get_gradients:

    def __init__(self,  chunk_end_dates, data): 
        self.chunk_end_dates = chunk_end_dates
        self.data = data

    def get_gradient(self, time_periods = (1,3,6,12)):
        self.chunk_dates = self.n_chunks(time_periods)
        self.chunked_data = self.split_data()
        self.gradients = self.get_gradients()
        

    def get_gradients(self):
        # get the gradients for a given chunk of data
        chunked_data = self.chunked_data
        gradients = {}

        for time_period, chunks in chunked_data.items():
            
            

        
    
    def split_data(self):
        # splits data_set based of chunk dates
        chunk_dates = self.chunk_dates
        data = self.data
        chunked_data = {}

        for n_months, dates in chunk_dates.items():
            chunked_data[n_months] = [data[(data.index >= start_date) & (data.index <= end_date)] for start_date, end_date in dates]

        return chunked_data

    
    def n_chunks(self, chunk_sizes):
        self.chunk_end_dates = chunk_end_dates
        
        n_chunk_dates = {}

        for date in chunk_end_dates:
            current_chunks = []
            
            for chunk in chunk_sizes:
                current_chunks.append((date - pd.DateOffset(months=chunk_size), date))

            n_chunk_dates[chunk] = chunk_end_dates

        return n_chunk_dates

# %%
class test():

    def __init__(self, number):
        self.number = number

    def square_root(self):
        return self.square() 

    def square(self):
        return self.number * self.number 

test_obj = test(4)
test_obj.square_root()
# Out:
# 16

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)


reg.score(X, y)
print(reg.coef_)
print(reg.intercept_)
reg.predict(np.array([[3, 5]]))
# Out:
# [1. 2.]
# 3.0
# array([16.])
